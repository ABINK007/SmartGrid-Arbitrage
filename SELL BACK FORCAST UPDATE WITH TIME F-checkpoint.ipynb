# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\vinaykumar\INTERNSHIP\SELL BACK DATASET.xlsx")

# %%
df
# Out:
#                 timestamp  season  cloud_cover day_type  hour  GHI_W_m2  \
# 0     2024-01-01 00:00:00  Winter           48  Weekday     0       0.0
# 1     2024-01-01 01:00:00  Winter           41  Weekday     1       0.0
# 2     2024-01-01 02:00:00  Winter           40  Weekday     2       0.0
# 3     2024-01-01 03:00:00  Winter           40  Weekday     3       0.0
# 4     2024-01-01 04:00:00  Winter           43  Weekday     4       0.0
# ...                   ...     ...          ...      ...   ...       ...
# 17539 2025-12-31 19:00:00  Winter           87  Weekday    19       0.0
# 17540 2025-12-31 20:00:00  Winter           72  Weekday    20       0.0
# 17541 2025-12-31 21:00:00  Winter           53  Weekday    21       0.0
# 17542 2025-12-31 22:00:00  Winter           46  Weekday    22       0.0
# 17543 2025-12-31 23:00:00  Winter           47  Weekday    23       0.0
#
#        solar_generation_kWh  household_demand_kWh  net_energy_kWh  \
# 0                       0.0                   0.4             0.0
# 1                       0.0                   0.4             0.0
# 2                       0.0                   0.4             0.0
# 3                       0.0                   0.4             0.0
# 4                       0.0                   0.4             0.0
# ...                     ...                   ...             ...
# 17539                   0.0                   3.0             0.0
# 17540                   0.0                   3.0             0.0
# 17541                   0.0                   3.0             0.0
# 17542                   0.0                   3.0             0.0
# 17543                   0.0                   0.8             0.0
#
#        battery_capacity_kWh  battery_level_kWh  grid_demand_kWh  \
# 0                        20                  6               12
# 1                        20                  6               12
# 2                        20                  6               12
# 3                        20                  6               12
# 4                        20                  6               12
# ...                     ...                ...              ...
# 17539                    20                 10               35
# 17540                    20                 10               35
# 17541                    20                 10               35
# 17542                    20                 10               35
# 17543                    20                  8               15
#
#        electricity_price
# 0                2.81351
# 1                2.48937
# 2                2.34995
# 3                2.42490
# 4                2.44748
# ...                  ...
# 17539            7.61391
# 17540            4.47728
# 17541            4.10381
# 17542            3.73799
# 17543            3.09301
#
# [17544 rows x 13 columns]

# %%
df['electricity_price'].describe()
# Out:
# count    17544.000000
# mean         4.289622
# std          2.602802
# min          0.049560
# 25%          2.695922
# 50%          3.429970
# 75%          4.752615
# max         10.000000
# Name: electricity_price, dtype: float64

# %%
df_1 = df.copy()

# %%
df.columns
# Out:
# Index(['timestamp', 'season', 'cloud_cover', 'day_type', 'hour', 'GHI_W_m2',
#        'solar_generation_kWh', 'household_demand_kWh', 'net_energy_kWh',
#        'battery_capacity_kWh', 'battery_level_kWh', 'grid_demand_kWh',
#        'electricity_price'],
#       dtype='object')

# %%
df['season'].unique()
# Out:
# array(['Winter', 'Summer', 'Monsoon'], dtype=object)

# %%
df['day_type'].unique()
# Out:
# array(['Weekday', 'Weekend'], dtype=object)

# %%
df_1
# Out:
#                 timestamp  season  cloud_cover day_type  hour  GHI_W_m2  \
# 0     2024-01-01 00:00:00  Winter           48  Weekday     0       0.0
# 1     2024-01-01 01:00:00  Winter           41  Weekday     1       0.0
# 2     2024-01-01 02:00:00  Winter           40  Weekday     2       0.0
# 3     2024-01-01 03:00:00  Winter           40  Weekday     3       0.0
# 4     2024-01-01 04:00:00  Winter           43  Weekday     4       0.0
# ...                   ...     ...          ...      ...   ...       ...
# 17539 2025-12-31 19:00:00  Winter           87  Weekday    19       0.0
# 17540 2025-12-31 20:00:00  Winter           72  Weekday    20       0.0
# 17541 2025-12-31 21:00:00  Winter           53  Weekday    21       0.0
# 17542 2025-12-31 22:00:00  Winter           46  Weekday    22       0.0
# 17543 2025-12-31 23:00:00  Winter           47  Weekday    23       0.0
#
#        solar_generation_kWh  household_demand_kWh  net_energy_kWh  \
# 0                       0.0                   0.4             0.0
# 1                       0.0                   0.4             0.0
# 2                       0.0                   0.4             0.0
# 3                       0.0                   0.4             0.0
# 4                       0.0                   0.4             0.0
# ...                     ...                   ...             ...
# 17539                   0.0                   3.0             0.0
# 17540                   0.0                   3.0             0.0
# 17541                   0.0                   3.0             0.0
# 17542                   0.0                   3.0             0.0
# 17543                   0.0                   0.8             0.0
#
#        battery_capacity_kWh  battery_level_kWh  grid_demand_kWh  \
# 0                        20                  6               12
# 1                        20                  6               12
# 2                        20                  6               12
# 3                        20                  6               12
# 4                        20                  6               12
# ...                     ...                ...              ...
# 17539                    20                 10               35
# 17540                    20                 10               35
# 17541                    20                 10               35
# 17542                    20                 10               35
# 17543                    20                  8               15
#
#        electricity_price
# 0                2.81351
# 1                2.48937
# 2                2.34995
# 3                2.42490
# 4                2.44748
# ...                  ...
# 17539            7.61391
# 17540            4.47728
# 17541            4.10381
# 17542            3.73799
# 17543            3.09301
#
# [17544 rows x 13 columns]

# %%
# Convert timestamp
df_1['timestamp'] = pd.to_datetime(df_1['timestamp'])
df_1 = df_1.sort_values(by='timestamp')

#  Encode season
season_map = {'Winter': 0, 'Summer': 1, 'Monsoon': 2}
df_1['season'] = df_1['season'].map(season_map)

#  Encode day_type
day_map = {'Weekday': 0, 'Weekend': 1}
df_1['day_type'] = df_1['day_type'].map(day_map)

# %%
df_1
# Out:
#                 timestamp  season  cloud_cover  day_type  hour  GHI_W_m2  \
# 0     2024-01-01 00:00:00       0           48         0     0       0.0
# 1     2024-01-01 01:00:00       0           41         0     1       0.0
# 2     2024-01-01 02:00:00       0           40         0     2       0.0
# 3     2024-01-01 03:00:00       0           40         0     3       0.0
# 4     2024-01-01 04:00:00       0           43         0     4       0.0
# ...                   ...     ...          ...       ...   ...       ...
# 17539 2025-12-31 19:00:00       0           87         0    19       0.0
# 17540 2025-12-31 20:00:00       0           72         0    20       0.0
# 17541 2025-12-31 21:00:00       0           53         0    21       0.0
# 17542 2025-12-31 22:00:00       0           46         0    22       0.0
# 17543 2025-12-31 23:00:00       0           47         0    23       0.0
#
#        solar_generation_kWh  household_demand_kWh  net_energy_kWh  \
# 0                       0.0                   0.4             0.0
# 1                       0.0                   0.4             0.0
# 2                       0.0                   0.4             0.0
# 3                       0.0                   0.4             0.0
# 4                       0.0                   0.4             0.0
# ...                     ...                   ...             ...
# 17539                   0.0                   3.0             0.0
# 17540                   0.0                   3.0             0.0
# 17541                   0.0                   3.0             0.0
# 17542                   0.0                   3.0             0.0
# 17543                   0.0                   0.8             0.0
#
#        battery_capacity_kWh  battery_level_kWh  grid_demand_kWh  \
# 0                        20                  6               12
# 1                        20                  6               12
# 2                        20                  6               12
# 3                        20                  6               12
# 4                        20                  6               12
# ...                     ...                ...              ...
# 17539                    20                 10               35
# 17540                    20                 10               35
# 17541                    20                 10               35
# 17542                    20                 10               35
# 17543                    20                  8               15
#
#        electricity_price
# 0                2.81351
# 1                2.48937
# 2                2.34995
# 3                2.42490
# 4                2.44748
# ...                  ...
# 17539            7.61391
# 17540            4.47728
# 17541            4.10381
# 17542            3.73799
# 17543            3.09301
#
# [17544 rows x 13 columns]

# %%
features = ['season','hour','day_type','grid_demand_kWh']
target = 'electricity_price'

# Step 1: copy dataset
df = df_1.copy()

# Step 2: sort by time
df = df.sort_values(by='timestamp')

# Step 3: split 80/20
split_index = int(len(df) * 0.8)

train = df.iloc[:split_index]
test = df.iloc[split_index:]

X_train = train[features]
y_train = train[target]

X_test = test[features]
y_test = test[target]

# %%
def train_model_cached(train, features, target):
    from statsmodels.tsa.statespace.sarimax import SARIMAX

    model = SARIMAX(
        train[target],
        exog=train[features],
        order=(1,1,1),
        seasonal_order=(1,1,1,24)
    )

    return model.fit(disp=False)

# %%
df = df.copy()
df = df.sort_values(by='timestamp')

split_index = int(len(df) * 0.8)

train = df.iloc[:split_index]
test = df.iloc[split_index:]

# %%
future_dates = pd.date_range(start='2026-01-01', end='2026-01-07 23:00', freq='H')

future_df = pd.DataFrame({'timestamp': future_dates})

# Hour
future_df['hour'] = future_df['timestamp'].dt.hour

# Day type
future_df['day_type'] = future_df['timestamp'].dt.weekday.apply(lambda x: 1 if x >= 5 else 0)

# Season (Jan → Winter)
future_df['season'] = 0

# Grid demand (simple assumption → use last known pattern)
future_df['grid_demand_kWh'] = df_1['grid_demand_kWh'].tail(len(future_df)).values
# Out:
# C:\Users\vinaykumar\AppData\Local\Temp\ipykernel_33728\1818797056.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   future_dates = pd.date_range(start='2026-01-01', end='2026-01-07 23:00', freq='H')

# %%
# Train model only once (like app3.py)
if 'model_fit' not in globals():
    model_fit = train_model_cached(train, features, target)

# Predictions
y_pred = model_fit.predict(
    start=len(train),
    end=len(train)+len(test)-1,
    exog=X_test
)

# Accuracy
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)

print("Test MAE:", round(mae, 3))

forecast_sarimax = model_fit.forecast(
    steps=len(future_df),
    exog=future_df[features]
)
# Out:
# Test MAE: 4.944

# %%
future_df['SARIMAX'] = forecast_sarimax.values[:len(future_df)]

# %%
df_temp = df.copy()
df_temp = df_temp.set_index('timestamp')

march_2024 = df_temp[(df_temp.index.year == 2024) &
                     (df_temp.index.month == 3) &
                     (df_temp.index.day <= 8)]

march_2025 = df_temp[(df_temp.index.year == 2025) &
                     (df_temp.index.month == 3) &
                     (df_temp.index.day <= 8)]

import matplotlib.pyplot as plt

# 2024
plt.figure(figsize=(10,4))
plt.plot(march_2024[target])
plt.title("Electricity Price (March 1–8, 2024)")
plt.xlabel("Time")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# 2025
plt.figure(figsize=(10,4))
plt.plot(march_2025[target])
plt.title("Electricity Price (March 1–8, 2025)")
plt.xlabel("Time")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Combine forecast with time info
forecast_df = future_df.copy()
forecast_df['hour'] = forecast_df['timestamp'].dt.hour
forecast_df['date'] = forecast_df['timestamp'].dt.date

# ✅ ADD THIS FILTER ONLY
forecast_df = forecast_df[
    (forecast_df['timestamp'] >= '2026-03-01') & 
    (forecast_df['timestamp'] <= '2026-03-08')
]
# ----------------------------- 
# 1. Plot Hourly Forecast (Better View) 
# ----------------------------- plt.figure(figsize=(14,6))
plt.figure(figsize=(14,6)) 
plt.plot(forecast_df['timestamp'], forecast_df['SARIMAX'],
color='orange') 
plt.title("Hourly Electricity Price Forecast (SARIMAX)") 
plt.xlabel("Date & Hour") 
plt.ylabel("Price") 
# Rotate for readability
plt.xticks(rotation=45) 
plt.grid(True) 
plt.show()

# -----------------------------
# 2. Average Price by Hour (KEY INSIGHT)
# -----------------------------

hourly_avg = forecast_df.groupby('hour')['SARIMAX'].mean()

plt.figure(figsize=(10,5))

# ✅ Path (line) + dots on every point
plt.plot(
    hourly_avg.index, 
    hourly_avg.values, 
    marker='o', 
    linestyle='-', 
    linewidth=2
)

# Title
plt.title("Average Price by Hour (Best Time to SELL)")
plt.xlabel("Hour of Day")
plt.ylabel("Average Price")
plt.grid(True)

# -----------------------------
# Highlight SELL hours (HIGH price)
# -----------------------------
high_threshold = hourly_avg.mean()
high_hours = hourly_avg[hourly_avg > high_threshold]

# ✅ Big RED dots for SELL points
plt.scatter(
    high_hours.index, 
    high_hours.values, 
    color='red', 
    s=100, 
    label='Best Sell Hours'
)


# Highlight highest price hours (SELL time)
high_threshold = hourly_avg.mean()
high_hours = hourly_avg[hourly_avg > high_threshold]

plt.scatter(high_hours.index, high_hours.values, color='red')

for h in high_hours.index:
    plt.text(h, high_hours[h], f"{h}", ha='center', va='bottom')

plt.show()

# -----------------------------
# 3. Show BEST HOURS TO SELL
# -----------------------------
best_hours = hourly_avg.nlargest(5)

print("BEST HOURS TO SELL (Highest Prices):")
print(best_hours)
# Out:
# BEST HOURS TO SELL (Highest Prices):
# hour
# 1    8.559560
# 0    8.404359
# 2    8.392036
# 3    8.142830
# 4    6.744523
# Name: SARIMAX, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ==============================
# 1. Create Future Data
# ==============================
def create_future_dataframe(start_date, end_date, df):

    # Generate hourly timestamps
    future_dates = pd.date_range(start=start_date, end=end_date, freq='h')

    future_df = pd.DataFrame({'timestamp': future_dates})

    # Hour feature
    future_df['hour'] = future_df['timestamp'].dt.hour

    # Day type (Weekend = 1, Weekday = 0)
    future_df['day_type'] = future_df['timestamp'].dt.weekday.apply(
        lambda x: 1 if x >= 5 else 0
    )

    # Season encoding
    def get_season(month):
        if month in [12, 1, 2]:
            return 0   # Winter
        elif month in [3, 4, 5]:
            return 1   # Summer
        else:
            return 2   # Monsoon

    future_df['season'] = future_df['timestamp'].dt.month.apply(get_season)

    # Demand (reuse recent pattern safely)
    demand_values = df['grid_demand_kWh'].tail(len(future_df)).values

    # If not enough rows, repeat values
    if len(demand_values) < len(future_df):
        demand_values = pd.Series(demand_values).repeat(
            (len(future_df) // len(demand_values)) + 1
        ).values[:len(future_df)]

    future_df['grid_demand_kWh'] = demand_values

    return future_df


# ==============================
# 2. Generate Future Data
# ==============================
future_df = create_future_dataframe(
    start_date='2026-03-01 00:00',
    end_date='2026-03-07 23:00',
    df=df_1
)


# ==============================
# 3. Forecast using SARIMAX
# ==============================
forecast = model_fit.forecast(
    steps=len(future_df),
    exog=future_df[features]
)

future_df['Forecast_Price'] = forecast.values


# ==============================
# 4. Plot Graph
# ==============================
plt.figure(figsize=(12,5))

plt.plot(
    future_df['timestamp'],
    future_df['Forecast_Price'],
    marker='o',
    linestyle='-'
)

plt.title("Electricity Price Forecast (March 1–7, 2026)")
plt.xlabel("Time")
plt.ylabel("Price")

plt.xticks(rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
future_df['Forecast_Price'].describe()
# Out:
# count    168.000000
# mean       4.585349
# std        1.975747
# min        1.252701
# 25%        3.048908
# 50%        4.243801
# 75%        5.160846
# max        8.737161
# Name: Forecast_Price, dtype: float64

# %%
future_df['Date'] = future_df['timestamp'].dt.date
future_df['Hour_Time'] = future_df['timestamp'].dt.strftime('%I %p').str.lstrip('0')

# %%
high_threshold = future_df['Forecast_Price'].quantile(0.75)
medium_threshold = future_df['Forecast_Price'].quantile(0.50)

def sellback_decision(price):
    if price >= high_threshold:
        return "Sell"
    elif price >= medium_threshold:
        return "Sell_Partial"
    else:
        return "Store"

# %%
future_df["Forecast_Decision"] = future_df["Forecast_Price"].apply(sellback_decision)
future_df['Date'] = future_df['timestamp'].dt.date
future_df['Hour_Time'] = future_df['timestamp'].dt.strftime('%I %p').str.lstrip('0')
result = future_df[['Date', 'Hour_Time', 'Forecast_Price', 'Forecast_Decision']]
print(result.to_string())
# Out:
#            Date Hour_Time  Forecast_Price Forecast_Decision
# 0    2026-03-01     12 AM        7.970230              Sell
# 1    2026-03-01      1 AM        8.005142              Sell
# 2    2026-03-01      2 AM        7.820670              Sell
# 3    2026-03-01      3 AM        7.592229              Sell
# 4    2026-03-01      4 AM        6.266743              Sell
# 5    2026-03-01      5 AM        4.514738      Sell_Partial
# 6    2026-03-01      6 AM        4.117940             Store
# 7    2026-03-01      7 AM        3.755051             Store
# 8    2026-03-01      8 AM        3.708360             Store
# 9    2026-03-01      9 AM        3.645074             Store
# 10   2026-03-01     10 AM        3.946080             Store
# 11   2026-03-01     11 AM        4.247459      Sell_Partial
# 12   2026-03-01     12 PM        2.996436             Store
# 13   2026-03-01      1 PM        2.251076             Store
# 14   2026-03-01      2 PM        1.799703             Store
# 15   2026-03-01      3 PM        1.413137             Store
# 16   2026-03-01      4 PM        1.252701             Store
# 17   2026-03-01      5 PM        1.773247             Store
# 18   2026-03-01      6 PM        1.686688             Store
# 19   2026-03-01      7 PM        2.127045             Store
# 20   2026-03-01      8 PM        2.757335             Store
# 21   2026-03-01      9 PM        3.248449             Store
# 22   2026-03-01     10 PM        2.765535             Store
# 23   2026-03-01     11 PM        3.898483             Store
# 24   2026-03-02     12 AM        8.359453              Sell
# 25   2026-03-02      1 AM        8.502885              Sell
# 26   2026-03-02      2 AM        8.333700              Sell
# 27   2026-03-02      3 AM        8.086522              Sell
# 28   2026-03-02      4 AM        6.695336              Sell
# 29   2026-03-02      5 AM        5.093396      Sell_Partial
# 30   2026-03-02      6 AM        4.820265      Sell_Partial
# 31   2026-03-02      7 AM        4.506876      Sell_Partial
# 32   2026-03-02      8 AM        4.459294      Sell_Partial
# 33   2026-03-02      9 AM        4.388285      Sell_Partial
# 34   2026-03-02     10 AM        4.691188      Sell_Partial
# 35   2026-03-02     11 AM        4.999957      Sell_Partial
# 36   2026-03-02     12 PM        3.803504             Store
# 37   2026-03-02      1 PM        3.067339             Store
# 38   2026-03-02      2 PM        2.633658             Store
# 39   2026-03-02      3 PM        2.278238             Store
# 40   2026-03-02      4 PM        2.117031             Store
# 41   2026-03-02      5 PM        2.667261             Store
# 42   2026-03-02      6 PM        2.597543             Store
# 43   2026-03-02      7 PM        3.051562             Store
# 44   2026-03-02      8 PM        3.634352             Store
# 45   2026-03-02      9 PM        4.076744             Store
# 46   2026-03-02     10 PM        3.567902             Store
# 47   2026-03-02     11 PM        4.527983      Sell_Partial
# 48   2026-03-03     12 AM        8.531688              Sell
# 49   2026-03-03      1 AM        8.705047              Sell
# 50   2026-03-03      2 AM        8.540082              Sell
# 51   2026-03-03      3 AM        8.287741              Sell
# 52   2026-03-03      4 AM        6.878440              Sell
# 53   2026-03-03      5 AM        5.317881              Sell
# 54   2026-03-03      6 AM        5.078848      Sell_Partial
# 55   2026-03-03      7 AM        4.779109      Sell_Partial
# 56   2026-03-03      8 AM        4.731282      Sell_Partial
# 57   2026-03-03      9 AM        4.658144      Sell_Partial
# 58   2026-03-03     10 AM        4.961570      Sell_Partial
# 59   2026-03-03     11 AM        5.272376              Sell
# 60   2026-03-03     12 PM        4.090970             Store
# 61   2026-03-03      1 PM        3.357341             Store
# 62   2026-03-03      2 PM        2.928539             Store
# 63   2026-03-03      3 PM        2.581706             Store
# 64   2026-03-03      4 PM        2.420287             Store
# 65   2026-03-03      5 PM        2.978702             Store
# 66   2026-03-03      6 PM        2.913627             Store
# 67   2026-03-03      7 PM        3.371413             Store
# 68   2026-03-03      8 PM        3.941106             Store
# 69   2026-03-03      9 PM        4.370063      Sell_Partial
# 70   2026-03-03     10 PM        3.854073             Store
# 71   2026-03-03     11 PM        4.766489      Sell_Partial
# 72   2026-03-04     12 AM        8.555549              Sell
# 73   2026-03-04      1 AM        8.737161              Sell
# 74   2026-03-04      2 AM        8.573359              Sell
# 75   2026-03-04      3 AM        8.319595              Sell
# 76   2026-03-04      4 AM        6.905299              Sell
# 77   2026-03-04      5 AM        5.356149              Sell
# 78   2026-03-04      6 AM        5.126519      Sell_Partial
# 79   2026-03-04      7 AM        4.830544      Sell_Partial
# 80   2026-03-04      8 AM        4.782648      Sell_Partial
# 81   2026-03-04      9 AM        4.708924      Sell_Partial
# 82   2026-03-04     10 AM        5.012494      Sell_Partial
# 83   2026-03-04     11 AM        5.323862              Sell
# 84   2026-03-04     12 PM        4.146605             Store
# 85   2026-03-04      1 PM        3.413675             Store
# 86   2026-03-04      2 PM        2.986218             Store
# 87   2026-03-04      3 PM        2.641753             Store
# 88   2026-03-04      4 PM        2.480275             Store
# 89   2026-03-04      5 PM        3.040947             Store
# 90   2026-03-04      6 PM        2.977153             Store
# 91   2026-03-04      7 PM        3.435977             Store
# 92   2026-03-04      8 PM        4.002059             Store
# 93   2026-03-04      9 PM        4.427312      Sell_Partial
# 94   2026-03-04     10 PM        3.909351             Store
# 95   2026-03-04     11 PM        4.808623      Sell_Partial
# 96   2026-03-05     12 AM        8.377755              Sell
# 97   2026-03-05      1 AM        8.561643              Sell
# 98   2026-03-05      2 AM        8.398162              Sell
# 99   2026-03-05      3 AM        8.144005              Sell
# 100  2026-03-05      4 AM        6.728332              Sell
# 101  2026-03-05      5 AM        5.182328              Sell
# 102  2026-03-05      6 AM        4.955290      Sell_Partial
# 103  2026-03-05      7 AM        4.660353      Sell_Partial
# 104  2026-03-05      8 AM        4.612439      Sell_Partial
# 105  2026-03-05      9 AM        4.538552      Sell_Partial
# 106  2026-03-05     10 AM        4.842162      Sell_Partial
# 107  2026-03-05     11 AM        5.153685      Sell_Partial
# 108  2026-03-05     12 PM        3.977572             Store
# 109  2026-03-05      1 PM        3.244835             Store
# 110  2026-03-05      2 PM        2.817749             Store
# 111  2026-03-05      3 PM        2.473936             Store
# 112  2026-03-05      4 PM        2.312443             Store
# 113  2026-03-05      5 PM        2.873737             Store
# 114  2026-03-05      6 PM        2.810296             Store
# 115  2026-03-05      7 PM        3.269406             Store
# 116  2026-03-05      8 PM        3.834492             Store
# 117  2026-03-05      9 PM        4.258724      Sell_Partial
# 118  2026-03-05     10 PM        3.740219             Store
# 119  2026-03-05     11 PM        4.635868      Sell_Partial
# 120  2026-03-06     12 AM        8.427495              Sell
# 121  2026-03-06      1 AM        8.612010              Sell
# 122  2026-03-06      2 AM        8.448617              Sell
# 123  2026-03-06      3 AM        8.194352              Sell
# 124  2026-03-06      4 AM        6.778300              Sell
# 125  2026-03-06      5 AM        5.233163              Sell
# 126  2026-03-06      6 AM        5.006840      Sell_Partial
# 127  2026-03-06      7 AM        4.712189      Sell_Partial
# 128  2026-03-06      8 AM        4.664269      Sell_Partial
# 129  2026-03-06      9 AM        4.590338      Sell_Partial
# 130  2026-03-06     10 AM        4.893959      Sell_Partial
# 131  2026-03-06     11 AM        5.205525              Sell
# 132  2026-03-06     12 PM        4.029728             Store
# 133  2026-03-06      1 PM        3.297043             Store
# 134  2026-03-06      2 PM        2.870059             Store
# 135  2026-03-06      3 PM        2.526427             Store
# 136  2026-03-06      4 PM        2.364929             Store
# 137  2026-03-06      5 PM        2.926395             Store
# 138  2026-03-06      6 PM        2.863051             Store
# 139  2026-03-06      7 PM        3.322240             Store
# 140  2026-03-06      8 PM        3.887052             Store
# 141  2026-03-06      9 PM        4.311002      Sell_Partial
# 142  2026-03-06     10 PM        3.792347             Store
# 143  2026-03-06     11 PM        4.686997      Sell_Partial
# 144  2026-03-07     12 AM        7.773111              Sell
# 145  2026-03-07      1 AM        7.957798              Sell
# 146  2026-03-07      2 AM        7.794430              Sell
# 147  2026-03-07      3 AM        7.540135              Sell
# 148  2026-03-07      4 AM        6.123978              Sell
# 149  2026-03-07      5 AM        4.579081      Sell_Partial
# 150  2026-03-07      6 AM        4.352955      Sell_Partial
# 151  2026-03-07      7 AM        4.058382             Store
# 152  2026-03-07      8 AM        4.010462             Store
# 153  2026-03-07      9 AM        3.936518             Store
# 154  2026-03-07     10 AM        4.240142             Store
# 155  2026-03-07     11 AM        4.551720      Sell_Partial
# 156  2026-03-07     12 PM        3.376009             Store
# 157  2026-03-07      1 PM        2.643339             Store
# 158  2026-03-07      2 PM        2.216384             Store
# 159  2026-03-07      3 PM        1.872801             Store
# 160  2026-03-07      4 PM        1.711302             Store
# 161  2026-03-07      5 PM        2.272815             Store
# 162  2026-03-07      6 PM        2.209498             Store
# 163  2026-03-07      7 PM        2.668709             Store
# 164  2026-03-07      8 PM        3.233445             Store
# 165  2026-03-07      9 PM        3.657318             Store
# 166  2026-03-07     10 PM        3.138622             Store
# 167  2026-03-07     11 PM        4.032996             Store
